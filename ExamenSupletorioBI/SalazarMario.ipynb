# %% [markdown]
# <h1>EJERCICIO 2:  Transformar datos en Python (5 PTOS)</h1>

# %% [markdown]
# <h2>Trabajar con el archivo test_ETL.csv. Cargar Datos</h2>

# %% [markdown]
# <h2>Crear un notebook ipynb.</h2>

# %% [markdown]
# <h2>Para comenzar este análisis exploratorio, primero importe bibliotecas para cargar data set y para graficar los datos.</h2>

# %% [markdown]
# <h2>Importar Librerias</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2>Cargar Datos - Dataframe</h2>

# %%
dataset = pd.read_csv("test_ETL.csv", encoding='utf-8', sep=',', header=0)
dataset = dataset.head(25).drop_duplicates()
dataset
# Out:
#     TOTAL_SESSIONS  TOTAL_GAME_TIME  ASSESSMENT_SESSION_COUNT INSTALLATION_ID  \
# 0               26           378218                         1        00abaee7
# 1               72          4864094                         4        01242218
# 2               61          2056732                         3        01242218
# 3               14            92624                         1        01242218
# 4               36           587169                         2        01242218
# 5               83          3109642                         3        01242218
# 6               51           941408                         2        01242218
# 7              124          8701318                         9        01242218
# 8               16           219996                         1        02256298
# 9              237         47389165                        17        02256298
# 10              94          7565205                         3        027e7ce5
# ...

# %% [markdown]
# <h2>Histogramas</h2>

# %%
dataset.plot(kind='bar',x='TOTAL_SESSIONS',y='ASSESSMENT_SESSION_COUNT')
plt.show()

# %%
dataset.plot(kind='bar',x='TITLE',y='ASSESSMENT_SESSION_COUNT')
plt.show()

# %%
dataset = dataset.head(25)
dataset.plot(kind='bar',x='TYPE',y='ASSESSMENT_SESSION_COUNT')
plt.show()

# %%
dataset = dataset.head(10)
dataset.plot(kind='bar',x='WORLD',y='ASSESSMENT_SESSION_COUNT')
plt.show()

# %%
dataset = dataset.head(10)
dataset.plot(kind='bar',x='ASSESSMENT_SESSION_COUNT',y='EVENT_COUNT')
plt.show()

# %%
dataset = dataset.head(10)
dataset.plot(kind='bar',x='WORLD',y='NUM_CORRECT')
plt.show()

# %%
dataset = dataset.head(10)
dataset.plot(kind='bar',x='WORLD',y='NUM_INCORRECT')
plt.show()

# %%
dataset = dataset.head(10)
dataset.plot(kind='bar',x='WORLD',y='ACCURACY_GROUP')
plt.show()

# %%
dataset = dataset.head(10)
plt.pie(dataset['ACCURACY_GROUP'], labels = dataset['TYPE'], autopct="%0.1f %%")
plt.axis("equal")
plt.show()

# %%
dataset = dataset.head(10)
plt.pie(dataset['ACCURACY_GROUP'], labels = dataset['WORLD'], autopct="%0.1f %%")
plt.axis("equal")
plt.show()
